# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import numpy as np
#       2 import matplotlib.pyplot as plt
#       4 # Define the matrix
#
# File ~\Documents\PYTHON OOP PROJECT\Numpy\numpy.py:14
#      12 import numpy as np
#      13 #Run in jupyter notebook
# ---> 14 array = np.array([[['a','b','c'], ['d','e','f'], ['g','h','i']],
#      15                   [['j','k','l'], ['m','n','o'], ['p','g','r']],
#      16                   [['s','t','u'], ['v','w','x'], ['y','z','']]])
#      18 word = array[0,0,2] + array[1,0,2] + array[0,0,0] + array[2,0,0] + array[2,0,0] + " " + array[0,2,2] + array[2,0,0] + " " + array[2,0,1] + array[0,2,1] + array[0,1,1] + " " + array[0,0,1] + array[0,1,1] + array[2,0,0] + array[2,0,1]
#      20 print(word)
#
# ...
